# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
def urunBilgisiKayıt():
    urunAd = input("Ürün adını girin: ")
    urunFiyat = input("Ürün fiyatını girin: ")
    
    with open("urunler.txt", "a") as dosya:
        dosya.write(f"Ürün Adı: {urunAd}, Fiyat: {urunFiyat}\n")
    
    print("Ürün bilgileri başarıyla kaydedildi.")


urunBilgisiKayıt()
# Out:
# Ürün bilgileri başarıyla kaydedildi.

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
def urunAdıDeğiştir(eskiAd, yeniAd):
    try:
        with open("urunler.txt", "r") as dosya:
            icerik = dosya.read()
        
        yeniIcerik = icerik.replace(eskiAd, yeniAd)
        
        with open("urunler.txt", "w") as dosya:
            dosya.write(yeniIcerik)
        
        print(f"'{eskiAd}' kelimesi başarıyla '{yeniAd}' kelimesi ile değiştirildi.")
    
    except FileNotFoundError:
        print("urunler.txt dosyası bulunamadı.")
    except Exception as e:
        print(f"Bir hata oluştu: {e}")


eskiAd = input("Değiştirilmesini istediğiniz kelimeyi girin: ")
yeniAd = input("Yeni kelimeyi girin: ")



urunAdıDeğiştir(eskiAd, yeniAd)
# Out:
# 'şeftali' kelimesi başarıyla 'kayısı' kelimesi ile değiştirildi.

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
class Vehicle:
    def __init__(self, name, speed, mileage):
        self.name = name
        self.speed = speed
        self.mileage = mileage

    def display_info(self):
        print(f"Name: {self.name} Speed: {self.speed} Mileage: {self.mileage}")

class Bus(Vehicle):
    pass


school_bus = Bus("School Volvo", 180, 12)


school_bus.display_info()
# Out:
# Name: School Volvo Speed: 180 Mileage: 12
