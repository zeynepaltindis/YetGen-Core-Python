# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
class Vehicle:
    def __init__(self, name, maxSpeed, mileage):
        self.name = name
        self.maxSpeed = maxSpeed
        self.mileage = mileage

    def seatingCapacity(self, capacity):
        return f"The seating capacity of a {self.name} is {capacity} passengers"

class Bus(Vehicle):
    def seatingCapacity(self, capacity=50):
        return super().seatingCapacity(capacity)


bus = Bus("Bus", 100, 15000)
print(bus.seatingCapacity())
# Out:
# The seating capacity of a Bus is 50 passengers

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
class Vehicle:
    def __init__(self, name, maxSpeed, mileage):
        self.name = name
        self.maxSpeed = maxSpeed
        self.mileage = mileage

    def seatingCapacity(self, capacity):
        return f"The seating capacity of a {self.name} is {capacity} passengers"

class Bus(Vehicle):
    def seatingCapacity(self, capacity=50):
        return super().seatingCapacity(capacity)

school_bus = Bus("School Bus", 80, 20000)

is_vehicle_instance = isinstance(school_bus, Vehicle)

print(f"School_bus is an instance of Vehicle: {is_vehicle_instance}")
# Out:
# School_bus is an instance of Vehicle: True
